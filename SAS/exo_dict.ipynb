# %%
import pandas as pd

# %%
dict = {'a':range(200,0,-10),'b':['toto']*20,'c':['blanc','noir']*10}
tableau = pd.DataFrame(dict)

# %%
tableau
# Out:
#       a     b      c
# 0   200  toto  blanc
# 1   190  toto   noir
# 2   180  toto  blanc
# 3   170  toto   noir
# 4   160  toto  blanc
# 5   150  toto   noir
# 6   140  toto  blanc
# 7   130  toto   noir
# 8   120  toto  blanc
# 9   110  toto   noir
# 10  100  toto  blanc
# 11   90  toto   noir
# 12   80  toto  blanc
# 13   70  toto   noir
# 14   60  toto  blanc
# 15   50  toto   noir
# 16   40  toto  blanc
# 17   30  toto   noir
# 18   20  toto  blanc
# 19   10  toto   noir

# %%
 dict ={'col1': range(24,34),
        'col2':range (1,11),
        'col3':['noir','blanc','blanc','blanc','blanc','noir','noir','noir','blanc','blanc']}
df = pd.DataFrame(dict)

# %%
df.tail(4)
# Out:
#    col1  col2   col3
# 6    30     7   noir
# 7    31     8   noir
# 8    32     9  blanc
# 9    33    10  blanc

# %%
print[df['col3']='blanc']
# Out:
#   File "<ipython-input-50-f01e5efeea3f>", line 1
#     print[df['col3']='blanc']
#                     ^
# SyntaxError: invalid syntax

# %%
titanic = pd.read_csv('https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv',sep='\t')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
len(titanic)
# Out:
# 156

# %%
titanic.tail(4)
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 152          153         0       3                 Meo, Mr. Alfonzo  male
# 153          154         0       3  van Billiard, Mr. Austin Blyler  male
# 154          155         0       3            Olsen, Mr. Ole Martin  male
# 155          156         0       1      Williams, Mr. Charles Duane  male
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 152  55.5      0      0  A.5. 11206   8.0500   NaN        S
# 153  40.5      0      2    A/5. 851  14.5000   NaN        S
# 154   NaN      0      0   Fa 265302   7.3125   NaN        S
# 155  51.0      0      1    PC 17597  61.3792   NaN        C

# %%
passager_majeur = titanic[(titanic['Age'] > 18)&(titanic['Sex']=='female')]

# %%
passager_majeur
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 11            12         1       1
# 15            16         1       2
# 18            19         0       3
# 25            26         1       3
# 40            41         0       3
# 41            42         0       2
# 44            45         1       3
# 52            53         1       1
# 53            54         1       2
# 56            57         1       2
# 61            62         1       1
# 66            67         1       2
# 79            80         1       3
# 85            86         1       3
# 88            89         1       1
# 98            99         1       2
# 100          101         0       3
# 106          107         1       3
# 113          114         0       3
# 123          124         1       2
# 132          133         0       3
# ...

# %%
enfant_survécu = titanic[((titanic['Age'] < 18)&(titanic['Survived']==1)) | ((titanic['Sex'] == 'male'))]

# %%
df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep='\t')

# %%
df.head(20)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
# 11         6         1                   Chicken Crispy Tacos
# 12         6         1                     Chicken Soft Tacos
# 13         7         1                           Chicken Bowl
# ...

# %%
# nbre de ligne et de colonnes
df.shape
# Out:
# (4622, 5)

# %%
sum(df['quantity'])
# Out:
# 4972

# %%
df [df['quantity'] ==max(df['quantity'])]
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#      item_price
# 3598    $44.25

# %%
df[df]
# Out:
# order_id                                      1443
# quantity                                        15
# item_name             Chips and Fresh Tomato Salsa
# choice_description                             NaN
# item_price                                 $44.25
# Name: 3598, dtype: object

# %%
df [df['item_name'] =='Chips and Fresh Tomato Salsa']
# Out:
#       order_id  quantity                     item_name choice_description  \
# 0            1         1  Chips and Fresh Tomato Salsa                NaN
# 25          13         1  Chips and Fresh Tomato Salsa                NaN
# 55          25         1  Chips and Fresh Tomato Salsa                NaN
# 89          39         1  Chips and Fresh Tomato Salsa                NaN
# 183         82         1  Chips and Fresh Tomato Salsa                NaN
# ...        ...       ...                           ...                ...
# 4231      1689         1  Chips and Fresh Tomato Salsa                NaN
# 4318      1722         1  Chips and Fresh Tomato Salsa                NaN
# 4324      1725         1  Chips and Fresh Tomato Salsa                NaN
# 4425      1764         1  Chips and Fresh Tomato Salsa                NaN
# 4503      1790         1  Chips and Fresh Tomato Salsa                NaN
#
#      item_price
# 0        $2.39
# 25       $2.39
# 55       $2.39
# ...

# %%
# chiffre d'affaire total
df.item_price.replace("$",'')

ca = df['quantity']*df['item_price']

# %%
ca.head()
# Out:
# 0            $2.39
# 1            $3.39
# 2            $3.39
# 3            $2.39
# 4    $16.98 $16.98
# dtype: object

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# # 1) importer
# # 2) nombre de lignes ? de colonnes ?
# # 3) nombre total de produits commandés sur tout le dataset
# # 4) trouver la commande qui comprend le plus de produits : quel est son id ? combien de produits contenait-elle ?
# # 5) afficher toutes les lignes correspondant à cette commande
# # 6) **calculer le chiffre d'affaire total sur tout le dataset

# %%
len(enfant_survécu)
# Out:
# 10
